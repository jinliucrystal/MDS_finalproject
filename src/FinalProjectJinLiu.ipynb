# %% [markdown]
# ## Final Project
# ## Jin Liu
# ### Find restaurants for users in NYC and show on Map in an automatable approach
# ### API: Yelp API

# %% [markdown]
# ### Data acquisition: This project intends to help users to find restaurants in NYC when they put the type of food they want. Also, the project will build a map to show locations of these restaurants. Firstly, I used APIs to obtain data and write an API client. Then, I wrote a for loop and function associated with API interaction. I also handle it in JSON.

# %%
import requests
import pandas as pd
import configparser
import config

# read configs
# config = configparser.ConfigParser()
# config.read('/Users/jinliu/Desktop/project/config.ini')

api_key = config.api_key
client_id = config.client_id

# Set the base URL for the Yelp API
base_url = 'https://api.yelp.com/v3/businesses/search'

headers = {
"Authorization": "Bearer " + api_key
}

# Set the parameters for the API request
params = {
    'term': 'cafe',  # search for restaurants
    'location': 'New York',  # in New York
    'limit': 50
}
response = requests.get(base_url, params=params, headers=headers)

# Get the list of businesses from the response
businesses = response.json()['businesses']

# Append the results for the current restaurant to the results list
df = pd.DataFrame(businesses)

# Create an empty list to store the results
results = []

# Iterate over a list of restaurant names
for terms in ['restaurant', 'cocktailbar', 'bar']:
    # Set the 'term' parameter to the current restaurant name
    params['term'] = terms
    for place in ['New York','long island city', 'jersey city']:
        params['location'] = place
    
        # Make the API request
        response = requests.get(base_url, params=params, headers=headers)

        # Get the list of businesses from the response
        businesses = response.json()['businesses']

        # Append the results for the current restaurant to the results list
        df = pd.concat([pd.DataFrame(businesses),df])

# The results list will contain the results for each restaurant

# %%
df.head()
# Out:
#                        id                                    alias  \
# 0  geaAzPXHBqH48SopnWKqXA          the-junto-attic-bar-jersey-city
# 1  _hvgCRW8Vw1n3Usr9RPoUg                   cellar-335-jersey-city
# 2  AZfcw8HHwstl-v6mTNIBIg        canopy-bar-and-bistro-jersey-city
# 3  r4SazXX-ISikdRYWbH-HAg                hudson-and-co-jersey-city
# 4  pqgteq-86xHmjinGwwb1ZA  rooftop-at-exchange-place-jersey-city-2
#
#                         name  \
# 0        The Junto Attic Bar
# 1                 Cellar 335
# 2        Canopy Bar & Bistro
# 3                Hudson & Co
# 4  Rooftop at Exchange Place
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/44ZMJC...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/XVOpAK...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/W3IJIk...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/327s7K...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/Lb_l7i...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/the-junto-attic-bar-j...            33
# 1  https://www.yelp.com/biz/cellar-335-jersey-cit...           673
# 2  https://www.yelp.com/biz/canopy-bar-and-bistro...            16
# 3  https://www.yelp.com/biz/hudson-and-co-jersey-...           693
# 4  https://www.yelp.com/biz/rooftop-at-exchange-p...           408
#
#                                           categories  rating  \
# 0               [{'alias': 'bars', 'title': 'Bars'}]     4.5
# 1  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 2  [{'alias': 'cocktailbars', 'title': 'Cocktail ...     4.0
# 3  [{'alias': 'gastropubs', 'title': 'Gastropubs'...     4.0
# 4  [{'alias': 'newamerican', 'title': 'American (...     3.0
#
#                                          coordinates        transactions  \
# 0   {'latitude': 40.718909, 'longitude': -74.045386}                  []
# 1  {'latitude': 40.7249692, 'longitude': -74.0515...  [delivery, pickup]
# 2   {'latitude': 40.71985, 'longitude': -74.0401546}          [delivery]
# 3   {'latitude': 40.720988, 'longitude': -74.031573}  [delivery, pickup]
# 4   {'latitude': 40.715958, 'longitude': -74.033869}                  []
#
#   price                                           location         phone  \
# 0   $$$  {'address1': '68 Mercer St', 'address2': '', '...
# 1    $$  {'address1': '335 Newark Ave', 'address2': '',...  +12012221422
# 2   NaN  {'address1': '159 Morgan St', 'address2': 'Fl ...  +12012414664
# 3   $$$  {'address1': '3 2nd St', 'address2': '', 'addr...  +12016857330
# 4   $$$  {'address1': '1 Exchange Pl', 'address2': '', ...  +15512567850
#
#     display_phone     distance
# 0                  1455.957344
# 1  (201) 222-1422   697.779032
# 2  (201) 241-4664  1789.000622
# 3  (201) 685-7330  2432.095875
# 4  (551) 256-7850  2497.272680

# %% [markdown]
# ### Data Cleaning, Transformation, and Organization
# ### I firstly reorganized the data and wrote a new category that contain only one tag for each restaurant. Therefore, the dataset is ready to use for an analysis on Python.

# %%
categories = []
for i in range(df.shape[0]):
    if type(df.iloc[i]['categories']) != type('i'):
        categories.append(df.iloc[i]['categories'][0]['alias'])
    else:
        categories.append(df.iloc[i]['categories'])

# %%
df = df.assign(categories2 = categories)
df
# Out:
#                         id                                    alias  \
# 0   geaAzPXHBqH48SopnWKqXA          the-junto-attic-bar-jersey-city
# 1   _hvgCRW8Vw1n3Usr9RPoUg                   cellar-335-jersey-city
# 2   AZfcw8HHwstl-v6mTNIBIg        canopy-bar-and-bistro-jersey-city
# 3   r4SazXX-ISikdRYWbH-HAg                hudson-and-co-jersey-city
# 4   pqgteq-86xHmjinGwwb1ZA  rooftop-at-exchange-place-jersey-city-2
# ..                     ...                                      ...
# 45  CBmrwh7jHn88M4v8Q9Qyyg           white-noise-coffee-co-brooklyn
# 46  GP-jlZ6DP1wZCJ8cfalxwA          bao-tea-house-mulberry-new-york
# 47  lYuebxgzj4UYsKuUpAlr0w                    café-kitsuné-brooklyn
# 48  qGvo8VHrY85b4Ze-JaIjYg                 ralphs-coffee-new-york-4
# 49  DWiOjg7wYFI4Dcb4d-1szg                  froth-new-york-new-york
#
#                          name  \
# 0         The Junto Attic Bar
# 1                  Cellar 335
# 2         Canopy Bar & Bistro
# 3                 Hudson & Co
# 4   Rooftop at Exchange Place
# ..                        ...
# 45      White Noise Coffee Co
# 46   BAO Tea House - Mulberry
# 47               Café Kitsuné
# 48             Ralph's Coffee
# 49             Froth New York
#
#                                             image_url  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/44ZMJC...      False
# 1   https://s3-media4.fl.yelpcdn.com/bphoto/XVOpAK...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/W3IJIk...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/327s7K...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/Lb_l7i...      False
# ..                                                ...        ...
# 45  https://s3-media2.fl.yelpcdn.com/bphoto/DlrPHd...      False
# 46  https://s3-media3.fl.yelpcdn.com/bphoto/9lKVbk...      False
# 47  https://s3-media4.fl.yelpcdn.com/bphoto/ddEExG...      False
# 48  https://s3-media3.fl.yelpcdn.com/bphoto/jFtjAP...      False
# 49  https://s3-media4.fl.yelpcdn.com/bphoto/veK34P...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/the-junto-attic-bar-j...            33
# 1   https://www.yelp.com/biz/cellar-335-jersey-cit...           673
# 2   https://www.yelp.com/biz/canopy-bar-and-bistro...            16
# 3   https://www.yelp.com/biz/hudson-and-co-jersey-...           693
# 4   https://www.yelp.com/biz/rooftop-at-exchange-p...           408
# ..                                                ...           ...
# 45  https://www.yelp.com/biz/white-noise-coffee-co...           136
# 46  https://www.yelp.com/biz/bao-tea-house-mulberr...             9
# 47  https://www.yelp.com/biz/caf%C3%A9-kitsun%C3%A...            17
# 48  https://www.yelp.com/biz/ralphs-coffee-new-yor...           128
# 49  https://www.yelp.com/biz/froth-new-york-new-yo...            34
#
#                                            categories  rating  \
# 0                [{'alias': 'bars', 'title': 'Bars'}]     4.5
# 1   [{'alias': 'newamerican', 'title': 'American (...     4.5
# 2   [{'alias': 'cocktailbars', 'title': 'Cocktail ...     4.0
# 3   [{'alias': 'gastropubs', 'title': 'Gastropubs'...     4.0
# 4   [{'alias': 'newamerican', 'title': 'American (...     3.0
# ..                                                ...     ...
# 45     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     4.0
# 46  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     4.5
# 47             [{'alias': 'cafes', 'title': 'Cafes'}]     3.0
# 48     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     4.5
# 49     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     4.5
#
#                                           coordinates        transactions  \
# 0    {'latitude': 40.718909, 'longitude': -74.045386}                  []
# 1   {'latitude': 40.7249692, 'longitude': -74.0515...  [delivery, pickup]
# 2    {'latitude': 40.71985, 'longitude': -74.0401546}          [delivery]
# 3    {'latitude': 40.720988, 'longitude': -74.031573}  [delivery, pickup]
# 4    {'latitude': 40.715958, 'longitude': -74.033869}                  []
# ..                                                ...                 ...
# 45  {'latitude': 40.6896242, 'longitude': -73.9882...          [delivery]
# 46   {'latitude': 40.717812, 'longitude': -73.997952}  [pickup, delivery]
# 47  {'latitude': 40.68644457276981, 'longitude': -...                  []
# 48  {'latitude': 40.7716587057718, 'longitude': -7...          [delivery]
# 49  {'latitude': 40.720316085086615, 'longitude': ...                  []
#
#    price                                           location         phone  \
# 0    $$$  {'address1': '68 Mercer St', 'address2': '', '...
# 1     $$  {'address1': '335 Newark Ave', 'address2': '',...  +12012221422
# 2    NaN  {'address1': '159 Morgan St', 'address2': 'Fl ...  +12012414664
# 3    $$$  {'address1': '3 2nd St', 'address2': '', 'addr...  +12016857330
# 4    $$$  {'address1': '1 Exchange Pl', 'address2': '', ...  +15512567850
# ..   ...                                                ...           ...
# 45    $$  {'address1': '57 Smith St', 'address2': '', 'a...  +17188580258
# 46   NaN  {'address1': '122 Mulberry St', 'address2': No...  +16463516759
# 47   NaN  {'address1': '112 Bond St', 'address2': '', 'a...
# 48    $$  {'address1': '888 Madison Ave', 'address2': ''...  +12124348000
# 49    $$  {'address1': '90 Rivington St', 'address2': ''...
#
#      display_phone     distance   categories2
# 0                   1455.957344          bars
# 1   (201) 222-1422   697.779032   newamerican
# 2   (201) 241-4664  1789.000622  cocktailbars
# 3   (201) 685-7330  2432.095875    gastropubs
# 4   (551) 256-7850  2497.272680   newamerican
# ..             ...          ...           ...
# 45  (718) 858-0258  1824.556563        coffee
# 46  (646) 351-6759  1415.116934         cafes
# 47                  2244.621968         cafes
# 48  (212) 434-8000  7745.004337        coffee
# 49                  1716.530161        coffee
#
# [359 rows x 17 columns]

# %% [markdown]
# ### Data wrangling and manipulation
# ### Then I tried to find a new dataframe that list top five categories of food that people like. This is used to give users some recommendations. The result I got from order review counts and ratings in a decending order. We can see that top five types are cocktailbars, coffee, italian, newamericna, and thai according to the Yelp review in NYC.

# %%
data = df.groupby('categories2')['review_count'].sum()
data1= data.reset_index(name = 'total_review')
data1
# Out:
#     categories2  total_review
# 0       arcades            52
# 1     argentine           507
# 2   asianfusion           398
# 3    australian           747
# 4      bakeries            71
# ..          ...           ...
# 69        uzbek            34
# 70       venues            13
# 71   vietnamese          2036
# 72  whiskeybars           840
# 73    wine_bars           681
#
# [74 rows x 2 columns]

# %%
data = df.groupby('categories2')['rating'].mean()
data2 = data.reset_index(name = 'mean_rating')
data2
# Out:
#     categories2  mean_rating
# 0       arcades     4.000000
# 1     argentine     4.500000
# 2   asianfusion     4.000000
# 3    australian     4.000000
# 4      bakeries     4.500000
# ..          ...          ...
# 69        uzbek     4.500000
# 70       venues     4.250000
# 71   vietnamese     4.300000
# 72  whiskeybars     4.500000
# 73    wine_bars     4.333333
#
# [74 rows x 2 columns]

# %%
# Join the two dataframes on the "business_id" column
data3 = data1.merge(data2, on='categories2')
data3
# Out:
#     categories2  total_review  mean_rating
# 0       arcades            52     4.000000
# 1     argentine           507     4.500000
# 2   asianfusion           398     4.000000
# 3    australian           747     4.000000
# 4      bakeries            71     4.500000
# ..          ...           ...          ...
# 69        uzbek            34     4.500000
# 70       venues            13     4.250000
# 71   vietnamese          2036     4.300000
# 72  whiskeybars           840     4.500000
# 73    wine_bars           681     4.333333
#
# [74 rows x 3 columns]

# %%
newdf = data3.sort_values(by=['total_review', 'mean_rating'], ascending=[False, False])
newdf = newdf.head(5)
newdf
# Out:
#      categories2  total_review  mean_rating
# 22        coffee         16262     4.396552
# 21  cocktailbars         15326     4.250000
# 37       italian         10873     4.107143
# 49   newamerican         10619     4.108696
# 67          thai          9410     4.388889

# %% [markdown]
# ### Data visualization
# ### Then I want to show restaurants' names and locations on a Map when a user has some ideas of the type of food they want. So, I built a map like this.

# %%
cocktailbars = df.loc[df['categories2'] == 'cocktailbars']
coffee = df.loc[df['categories2'] == 'coffee']
italian = df.loc[df['categories2'] == 'italian']
newamerican = df.loc[df['categories2'] == 'newamerican']
thai = df.loc[df['categories2'] == 'thai']

# %%
import folium
from folium.plugins import MarkerCluster
# Create a map centered on New York City
m = folium.Map(location=[40.7128, -74.0060], zoom_start=11)

# Create a marker cluster object
marker_cluster = MarkerCluster().add_to(m)

# Add a marker for each business
for b in range(cocktailbars.shape[0]):
    folium.Marker(
        location=[cocktailbars.iloc[b]['coordinates']['latitude'], cocktailbars.iloc[b]['coordinates']['longitude']],popup=cocktailbars.iloc[b]['name']).add_to(marker_cluster)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba107bd61d9d3a3fe366e6fa2064da1e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba107bd61d9d3a3fe366e6fa2064da1e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba107bd61d9d3a3fe366e6fa2064da1e = L.map(
#                 &quot;map_ba107bd61d9d3a3fe366e6fa2064da1e&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_adb27f6c024f71ce43b5c4b196f284ac = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ba107bd61d9d3a3fe366e6fa2064da1e);
#
#
#             var marker_cluster_edf020ce90f405e89939c0d68a3cb036 = L.markerClusterGroup(
#                 {}
#             );
#             map_ba107bd61d9d3a3fe366e6fa2064da1e.addLayer(marker_cluster_edf020ce90f405e89939c0d68a3cb036);
#
#
#             var marker_aaea3afe4cc624c3565604e17fc8a103 = L.marker(
#                 [40.71985, -74.0401546],
#                 {}
#             ).addTo(marker_cluster_edf020ce90f405e89939c0d68a3cb036);
#
#
#         var popup_188bcc65d55dd01ebd66cce70ced77b9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9da83d2e0488ed8b03c21c2cc5418d97 = $(`&lt;div id=&quot;html_9da83d2e0488ed8b03c21c2cc5418d97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Canopy Bar &amp; Bistro&lt;/div&gt;`)[0];
#                 popup_188bcc65d55dd01ebd66cce70ced77b9.setContent(html_9da83d2e0488ed8b03c21c2cc5418d97);
#
#
#
#         marker_aaea3afe4cc624c3565604e17fc8a103.bindPopup(popup_188bcc65d55dd01ebd66cce70ced77b9)
#         ;
#
#
#
#
#             var marker_da8fe962e3cdf242cce7f8a6a05d0fb4 = L.marker(
#                 [40.721315204191, -74.045283556493],
#                 {}
#             ).addTo(marker_cluster_edf020ce90f405e89939c0d68a3cb036);
#
#
#         var popup_4f253805245c34c248bbbac203d6a603 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_27f8565edb269a8e85016da51705e9e3 = $(`&lt;div id=&quot;html_27f8565edb269a8e85016da51705e9e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Archer&lt;/div&gt;`)[0];
#                 popup_4f253805245c34c248bbbac203d6a603.setContent(html_27f8565edb269a8e85016da51705e9e3);
#
#
#
#         marker_da8fe962e3cdf242cce7f8a6a05d0fb4.bindPopup(popup_4f253805245c34c248bbbac203d6a603)
#         ;
#
#
#
#
#             var marker_a8dcf4799b9f9878daf81f3e14a76830 = L.marker(
#                 [40.72138, -74.04239],
#                 {}
#             ).addTo(marker_cluster_edf020ce90f405e89939c0d68a3cb036);
#
#
#         var popup_694bfe96ef0370cea40515287857d4b9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4af9ae0f11ba391f3b16c60759b9c384 = $(`&lt;div id=&quot;html_4af9ae0f11ba391f3b16c60759b9c384&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dullboy&lt;/div&gt;`)[0];
#                 popup_694bfe96ef0370cea40515287857d4b9.setContent(html_4af9ae0f11ba391f3b16c60759b9c384);
#
#
#
#         marker_a8dcf4799b9f9878daf81f3e14a76830.bindPopup(popup_694bfe96ef0370cea40515287857d4b9)
#         ;
#
#
#
#
#             var marker_ed2322ed80cd145f1e62b459f9bdb6fd = L.marker(
#                 [40.73977, -74.04679],
#                 {}
#             ).addTo(marker_cluster_edf020ce90f405e89939c0d68a3cb036);
#
#
#         var popup_2eb4b46eba9882f72e57f54f83239b43 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_adefaa65c5fe7623850dcbaa7e2c44df = $(`&lt;div id=&quot;html_adefaa65c5fe7623850dcbaa7e2c44df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Low Fidelity&lt;/div&gt;`)[0];
#                 popup_2eb4b46eba9882f72e57f54f83239b43.setContent(html_adefaa65c5fe7623850dcbaa7e2c44df);
#
#
#
#         marker_ed2322ed80cd145f1e62b459f9bdb6fd.bindPopup(popup_2eb4b46eba9882f72e57f54f83239b43)
#         ;
#
#
#
#
#             var marker_4dec9a8a5e64801e9d7455bf37ac85fc = L.marker(
#                 [40.71883, -74.04551],
#                 {}
#             ).addTo(marker_cluster_edf020ce90f405e

# %%
categ = set(['bars', 'bars', 'newamerican', 'beergardens', 'beergardens', 'newamerican', 'cocktailbars', 
                  'southern', 'pubs', 'gastropubs', 'divebars', 'distilleries', 'bars', 'newamerican', 
                  'cocktailbars', 'cuban', 'pubs', 'bars', 'mini_golf', 'breakfast_brunch', 'cocktailbars', 
                  'australian', 'lounges', 'cocktailbars', 'newamerican', 'chicken_wings', 'breweries', 'venues', 
                  'bars', 'newamerican', 'arcades', 'breweries', 'pizza', 'bars', 'wine_bars', 'cafes', 'bars',
                  'bars', 'lounges', 'pubs', 'newamerican', 'latin', 'lounges', 'lounges', 'bars', 'argentine',
                  'wine_bars', 'bars', 'gastropubs', 'gastropubs', 'divebars', 'pizza', 'cocktailbars', 'italian',
                  'bowling', 'divebars', 'pizza', 'coffee', 'brazilian', 'mexican', 'irish', 'bars', 'musicvenues',
                  'peruvian', 'bars', 'lounges', 'newamerican', 'breweries', 'cocktailbars', 'tradamerican',
                  'newamerican', 'pizza', 'szechuan', 'cocktailbars', 'newamerican', 'cocktailbars', 'bars',
                  'speakeasies', 'cocktailbars', 'cocktailbars', 'cocktailbars', 'lounges', 'mini_golf',
                  'cocktailbars', 'asianfusion', 'venues', 'lounges', 'beerbar', 'cocktailbars', 'bars',
                  'cocktailbars', 'bars', 'cocktailbars', 'cocktailbars', 'bars', 'lounges', 'coffee', 'bars',
                  'cocktailbars', 'cocktailbars', 'divebars', 'cocktailbars', 'divebars', 'cocktailbars',
                  'mediterranean', 'cocktailbars', 'cocktailbars', 'bars', 'cocktailbars', 'divebars', 'cocktailbars',
                  'cocktailbars', 'cocktailbars', 'cocktailbars', 'whiskeybars', 'cocktailbars', 'bars', 'lounges',
                  'bars', 'cocktailbars', 'bars', 'wine_bars', 'cocktailbars', 'asianfusion', 'seafood',
                  'cocktailbars', 'asianfusion', 'seafood', 'cocktailbars', 'asianfusion', 'seafood', 'newamerican',
                  'korean', 'noodles', 'newamerican', 'gastropubs', 'japanese', 'italian', 'caribbean', 'newamerican',
                  'thai', 'korean', 'chinese', 'cocktailbars', 'newamerican', 'cocktailbars', 'newamerican', 'cuban',
                  'italian', 'pizza', 'vegan', 'latin', 'pizza', 'seafood', 'chinese', 'newamerican', 'mexican',
                  'thai', 'tradamerican', 'beerbar', 'desserts', 'beerbar', 'cocktailbars', 'mexican', 'tacos',
                  'italian', 'vietnamese', 'italian', 'chinese', 'cocktailbars', 'ramen', 'brazilian', 'seafood',
                  'vietnamese', 'breakfast_brunch', 'vietnamese', 'bars', 'bangladeshi', 'malaysian', 'indpak',
                  'portuguese', 'newamerican', 'newamerican', 'peruvian', 'szechuan', 'chinese', 'pizza', 'ramen',
                  'chicken_wings', 'chinese', 'pizza', 'noodles', 'chicken_wings', 'japanese', 'mexican', 'thai',
                  'latin', 'italian', 'argentine', 'szechuan', 'bubbletea', 'chinese', 'pizza', 'argentine', 'italian',
                  'japanese', 'thai', 'tacos', 'seafood', 'bbq', 'thai', 'italian', 'sushi', 'french', 'chinese',
                  'vietnamese', 'spanish', 'modern_european', 'szechuan', 'dimsum', 'bars', 'latin', 'filipino',
                  'gastropubs', 'sushi', 'pizza', 'pizza', 'peruvian', 'coffee', 'bars', 'chinese', 'italian', 'thai',
                  'shanghainese', 'food_court', 'pizza', 'szechuan', 'newamerican', 'cocktailbars', 'newamerican',
                  'breakfast_brunch', 'korean', 'mediterranean', 'pizza', 'japanese', 'japanese', 'japanese',
                  'chinese', 'newamerican', 'italian', 'korean', 'spanish', 'thai', 'grocery', 'italian', 'steak',
                  'korean', 'uzbek', 'bars', 'asianfusion', 'tradamerican', 'buffets', 'italian', 'seafood',
                  'chinese', 'korean', 'italian', 'mideastern', 'vietnamese', 'seafood', 'taiwanese', 'japanese',
                  'thai', 'japanese', 'french', 'cocktailbars', 'seafood', 'thai', 'hotdogs', 'korean', 'vietnamese',
                  'coffee', 'coffee', 'coffee', 'cafes', 'coffee', 'coffee', 'bookstores', 'australian', 'coffee',
                  'mideastern', 'coffee', 'coffee', 'breakfast_brunch', 'coffee', 'coffee', 'cafes', 'coffee',
                  'coffee', 'bookstores', 'coffee', 'tea', 'coffee', 'coffee', 'coffee', 'coffee', 'coffee',
                  'coffee', 'coffee', 'coffee', 'cafes', 'bakeries', 'breakfast_brunch', 'cafes', 'coffee', 'cafes',
                  'coffee', 'cafes', 'coffee', 'cafes', 'coffee', 'cafes', 'coffee', 'coffee', 'cafes', 'bakeries',
                  'coffee', 'coffee', 'coffee', 'coffee', 'bakeries','bars', 'newamerican', 'cocktailbars', 'gastropubs', 
                  'newamerican', 'newamerican', 'divebars', 'cocktailbars', 'pubs', 
                  'pubs', 'beergardens', 'cocktailbars', 'bars', 'caribbean', 'gaybars', 
                  'lounges', 'cocktailbars', 'tradamerican', 'bars', 'beerbar', 'cocktailbars'])

# %% [markdown]
# ### I made categories to be unique and not reptitive. This is useful when I build a function for next step.

# %%
categ
# Out:
# {'arcades',
#  'argentine',
#  'asianfusion',
#  'australian',
#  'bakeries',
#  'bangladeshi',
#  'bars',
#  'bbq',
#  'beerbar',
#  'beergardens',
#  'bookstores',
#  'bowling',
#  'brazilian',
#  'breakfast_brunch',
#  'breweries',
#  'bubbletea',
#  'buffets',
#  'cafes',
#  'caribbean',
#  'chicken_wings',
#  'chinese',
#  'cocktailbars',
#  'coffee',
#  'cuban',
#  'desserts',
#  'dimsum',
#  'distilleries',
#  'divebars',
#  'filipino',
#  'food_court',
#  'french',
#  'gastropubs',
#  'gaybars',
#  'grocery',
#  'hotdogs',
#  'indpak',
#  'irish',
#  'italian',
#  'japanese',
#  'korean',
#  'latin',
#  'lounges',
#  'malaysian',
#  'mediterranean',
#  'mexican',
#  'mideastern',
#  'mini_golf',
#  'modern_european',
#  'musicvenues',
#  'newamerican',
#  'noodles',
#  'peruvian',
#  'pizza',
#  'portuguese',
#  'pubs',
#  'ramen',
#  'seafood',
#  'shanghainese',
#  'southern',
#  'spanish',
#  'speakeasies',
#  'steak',
#  'sushi',
#  'szechuan',
#  'tacos',
#  'taiwanese',
#  'tea',
#  'thai',
#  'tradamerican',
#  'uzbek',
#  'vegan',
#  'venues',
#  'vietnamese',
#  'whiskeybars',
#  'wine_bars'}

# %% [markdown]
# ### I used a function to export repetitive or difficult tasks. By using this function, when users put the term (eg: a type of food), they can automatically get the map that show restaurants' names and locations on a map. If users type the term not within the category, there will be an error

# %%
def get_map(term):
    api_key = config.api_key
    headers = {
      "Authorization": "Bearer " + api_key
    }
    # Set the base URL for the Yelp API
    base_url = 'https://api.yelp.com/v3/businesses/search'

    # Set the parameters for the API request
    params = {
        'term': 'restaurant' , # search for restaurants
        'location': 'New York' ,# in New York
        'limit': 50
    }
    response = requests.get(base_url, params=params, headers=headers)

    # Get the list of businesses from the response
    businesses = response.json()['businesses']

    # Append the results for the current restaurant to the results list
    df = pd.DataFrame(businesses)

    # Iterate over a list of restaurant names
    for terms in ['restaurant', 'cocktailbar', 'bar']:
        # Set the 'term' parameter to the current restaurant name
        params['term'] = terms
        for place in ['New York','long island city', 'jersey city']:
            params['location'] = place

            # Make the API request
            response = requests.get(base_url, params=params, headers=headers)

            # Get the list of businesses from the response
            businesses = response.json()['businesses']

            # Append the results for the current restaurant to the results list
            df = pd.concat([pd.DataFrame(businesses),df])
    categories = []
    for i in range(df.shape[0]):
        if type(df.iloc[i]['categories']) != type('i'):
            categories.append(df.iloc[i]['categories'][0]['alias'])
        else:
            categories.append(df.iloc[i]['categories'])

    df = df.assign(categories2 = categories)
    looking_for = df.loc[df['categories2'] == term]
    
        # Create a map centered on New York City
    m = folium.Map(location=[40.7128, -74.0060], zoom_start=11)

    # Create a marker cluster object
    marker_cluster = MarkerCluster().add_to(m)

    # Add a marker for each business
    for b in range(looking_for.shape[0]):
        folium.Marker(
            location=[looking_for.iloc[b]['coordinates']['latitude'], looking_for.iloc[b]['coordinates']['longitude']],popup=cocktailbars.iloc[b]['name']).add_to(marker_cluster)

    # Display the map
    if looking_for.shape[0] == 0:
        return None
    return m

# %%
get_map('spanish')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f1d32907d6e9ef0b464961644246ab5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f1d32907d6e9ef0b464961644246ab5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f1d32907d6e9ef0b464961644246ab5 = L.map(
#                 &quot;map_6f1d32907d6e9ef0b464961644246ab5&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b9faa77e04d5d04335030cb566e629a6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6f1d32907d6e9ef0b464961644246ab5);
#
#
#             var marker_cluster_846a283177fcb46097d923baf28d6264 = L.markerClusterGroup(
#                 {}
#             );
#             map_6f1d32907d6e9ef0b464961644246ab5.addLayer(marker_cluster_846a283177fcb46097d923baf28d6264);
#
#
#             var marker_f1f4a20faa1c49376f9b55ff3a9af90d = L.marker(
#                 [40.75833, -73.92794],
#                 {}
#             ).addTo(marker_cluster_846a283177fcb46097d923baf28d6264);
#
#
#         var popup_7902957e7d62c2a794b1661a01c914ad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_39588ea770dcc74e1223db4785742f9d = $(`&lt;div id=&quot;html_39588ea770dcc74e1223db4785742f9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Canopy Bar &amp; Bistro&lt;/div&gt;`)[0];
#                 popup_7902957e7d62c2a794b1661a01c914ad.setContent(html_39588ea770dcc74e1223db4785742f9d);
#
#
#
#         marker_f1f4a20faa1c49376f9b55ff3a9af90d.bindPopup(popup_7902957e7d62c2a794b1661a01c914ad)
#         ;
#
#
#
#
#             var marker_b0280b745e0167bc782faea452e25034 = L.marker(
#                 [40.7249227818105, -74.00215536627918],
#                 {}
#             ).addTo(marker_cluster_846a283177fcb46097d923baf28d6264);
#
#
#         var popup_06a131b62640be0297f3fe827fabe812 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a8bc0f27d09d1df41deddb1a9f6b8507 = $(`&lt;div id=&quot;html_a8bc0f27d09d1df41deddb1a9f6b8507&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Archer&lt;/div&gt;`)[0];
#                 popup_06a131b62640be0297f3fe827fabe812.setContent(html_a8bc0f27d09d1df41deddb1a9f6b8507);
#
#
#
#         marker_b0280b745e0167bc782faea452e25034.bindPopup(popup_06a131b62640be0297f3fe827fabe812)
#         ;
#
#
#
#
#             var marker_ae078785b488a0f0c31100ce3b42598f = L.marker(
#                 [40.7249227818105, -74.00215536627918],
#                 {}
#             ).addTo(marker_cluster_846a283177fcb46097d923baf28d6264);
#
#
#         var popup_0804f657c36fc16e3acbded84e6bcba7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8f71b7a72136fc025472ed6994711322 = $(`&lt;div id=&quot;html_8f71b7a72136fc025472ed6994711322&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dullboy&lt;/div&gt;`)[0];
#                 popup_0804f657c36fc16e3acbded84e6bcba7.setContent(html_8f71b7a72136fc025472ed6994711322);
#
#
#
#         marker_ae078785b488a0f0c31100ce3b42598f.bindPopup(popup_0804f657c36fc16e3acbded84e6bcba7)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Here, I want to write some simple tests that make sure the function work both for normal condition and exception cases.

# %%
import folium
from folium.plugins import MarkerCluster
def test_get_map(term):
    m = folium.Map(location=[40.7128, -74.0060], zoom_start=11)
    expected = m
    actual = get_map(term)
    assert type(actual) == type(expected), "Result should be an map object"
    return actual

# %%
test_get_map('spanish')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eb14c8f892b7c50efa04dd0cff5934ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eb14c8f892b7c50efa04dd0cff5934ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eb14c8f892b7c50efa04dd0cff5934ac = L.map(
#                 &quot;map_eb14c8f892b7c50efa04dd0cff5934ac&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af37afb0918924cbd4b62586dbb49d18 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_eb14c8f892b7c50efa04dd0cff5934ac);
#
#
#             var marker_cluster_de635e448ce6e96f0d60c185b682a0aa = L.markerClusterGroup(
#                 {}
#             );
#             map_eb14c8f892b7c50efa04dd0cff5934ac.addLayer(marker_cluster_de635e448ce6e96f0d60c185b682a0aa);
#
#
#             var marker_25e9a42df08cae13f9a6eb873257a78f = L.marker(
#                 [40.75833, -73.92794],
#                 {}
#             ).addTo(marker_cluster_de635e448ce6e96f0d60c185b682a0aa);
#
#
#         var popup_2e1ee8a28311cf16368450744510f2d5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b0e49556f61d076711eaf69483bc5cb = $(`&lt;div id=&quot;html_6b0e49556f61d076711eaf69483bc5cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Canopy Bar &amp; Bistro&lt;/div&gt;`)[0];
#                 popup_2e1ee8a28311cf16368450744510f2d5.setContent(html_6b0e49556f61d076711eaf69483bc5cb);
#
#
#
#         marker_25e9a42df08cae13f9a6eb873257a78f.bindPopup(popup_2e1ee8a28311cf16368450744510f2d5)
#         ;
#
#
#
#
#             var marker_9fbd10764310dbca62b0d51eb2a91c8e = L.marker(
#                 [40.7249227818105, -74.00215536627918],
#                 {}
#             ).addTo(marker_cluster_de635e448ce6e96f0d60c185b682a0aa);
#
#
#         var popup_5222d750ecb602ebac02a8150d6332f2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5c4aec98ae6653c7e2b15851a8c39a5c = $(`&lt;div id=&quot;html_5c4aec98ae6653c7e2b15851a8c39a5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Archer&lt;/div&gt;`)[0];
#                 popup_5222d750ecb602ebac02a8150d6332f2.setContent(html_5c4aec98ae6653c7e2b15851a8c39a5c);
#
#
#
#         marker_9fbd10764310dbca62b0d51eb2a91c8e.bindPopup(popup_5222d750ecb602ebac02a8150d6332f2)
#         ;
#
#
#
#
#             var marker_77dd852c39e19f1ec8f95b79acd6f9ba = L.marker(
#                 [40.7249227818105, -74.00215536627918],
#                 {}
#             ).addTo(marker_cluster_de635e448ce6e96f0d60c185b682a0aa);
#
#
#         var popup_64cd014e39442915ec65b8c67f7e2047 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_14327c2877eda6aa95f43f31d364381f = $(`&lt;div id=&quot;html_14327c2877eda6aa95f43f31d364381f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dullboy&lt;/div&gt;`)[0];
#                 popup_64cd014e39442915ec65b8c67f7e2047.setContent(html_14327c2877eda6aa95f43f31d364381f);
#
#
#
#         marker_77dd852c39e19f1ec8f95b79acd6f9ba.bindPopup(popup_64cd014e39442915ec65b8c67f7e2047)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pytest
def test():
    with pytest.raises(AssertionError):
        test_get_map('somethingraondom')
